# %% [markdown]
# Private and public attr method
# =

# %%
class A():
    __a = 1  #__ means private
    b = __a + 1


    def __add(self):
        return self.__a + self.b
    
    def public_add(self):
        return self.__add()
    

obj = A()
print(obj.b) #2
# Out:
# 2

# %%
class BankAccount():
    accountholder = "Ram"
    __balance = 1000

    def withdraw(self, amount):
        self.__balance -= amount
        return amount
    
    def deposit(self, amount):
        self.__balance += amount
        return f"{self.accountholder}, your account credited by {amount}"
    
    
    def showbalance(self):
        return f"The new balance is {self.__balance}"
    

class StudentAccount(BankAccount):
    studentId = 123

    def paylibraryfee(self, amount):
            return f"Your pay library fee is {self.withdraw(amount)}"

obj = StudentAccount()
print(obj.deposit(200))
print(obj.paylibraryfee(100))
print(obj.showbalance())
# Out:
# Ram, your account credited by 200
# Your pay library fee is 100
# The new balance is 1100
